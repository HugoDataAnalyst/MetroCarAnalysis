# %%
#import needed library
import pandas as pd

# Merge all the daily data for the funnel
csv_directory = '../CSV/'
merged_data = pd.DataFrame()

# List of file names
file_names = ["funneldatadaily1.csv", "funneldatadaily2.csv", "funneldatadaily3.csv", "funneldatadaily4.csv",
              "funneldatadaily5.csv", "funneldatadaily6.csv", "funneldatadaily7.csv", "funneldatadaily8.csv",
              "funneldatadaily9.csv", "funneldatadaily10.csv", "funneldatadaily11.csv", "funneldatadaily12.csv",
              "funneldatadaily13.csv"]

# Loop through each file and merge it into the DataFrame
for file_name in file_names:
    df = pd.read_csv(csv_directory + file_name)
    merged_data = pd.concat([merged_data, df], ignore_index=True)

# Specify the path to save the merged file
merged_file_path = '../CSV/fulldatadaily.csv'

# Save the merged data to a new CSV file
merged_data.to_csv(merged_file_path, index=False)

# %%
#Import necessary libraries
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import ipywidgets as widgets
from ipywidgets import interactive, Layout, Output
from IPython.display import display, clear_output
from datetime import datetime


# Create global filtering options
# Add date pickers for selecting the date range
start_date_picker = widgets.DatePicker(
    description='Start Date:',
    value=pd.Timestamp('2021-01-01'),
    disabled=False
)
end_date_picker = widgets.DatePicker(
    description='End Date:',
    value=pd.Timestamp('2022-04-24'),
    disabled=False
)
# Add checkboxes for merging platform and age range data
merge_platforms_checkbox = widgets.Checkbox(
    description='Merge Platforms',
    value=False, 
    disabled=False
)
merge_agerange_checkbox = widgets.Checkbox(
    description='Merge Age Range',
    value=False, 
    disabled=False
) 

# Create a function to display Daily Downloads per Platform
def display_download_platform():
    # Load the dataset
    df = pd.read_csv('../CSV/funneldatawithdailydates.csv')
    df = df[df['funnel_step'] == 1]
    
    # Convert the 'daily_date' column to datetime
    df['daily_date'] = pd.to_datetime(df['daily_date'], format='%Y-%m-%d')

    # Filter the dataset based on the date range and platform
    def filter_data(start_date, end_date, start_platform, end_platform):
        start_date = pd.Timestamp(start_date).date()
        end_date = pd.Timestamp(end_date).date()
        filtered_df = df[
        (df['daily_date'].dt.date >= start_date) & 
        (df['daily_date'].dt.date <= end_date)  & 
        (df['platform'] >= start_platform) &
        (df['platform'] <= end_platform)]
        return filtered_df

    # Define the default start and end platform ranges
    default_start_platform_range = 'android'
    default_end_platform_range = 'web'
    
    # Add a platform filtering option based on the dataset
    #Set default platform filtering option and create Dropdown Widgets
    start_platform_range_picker = widgets.Dropdown(
        description='Start Platform:',
        options=df['platform'].unique(),
        value=default_start_platform_range,
        disabled=False
    )
    end_platform_range_picker = widgets.Dropdown(
        description='End Platform:',
        options=df['platform'].unique(),
        value=default_end_platform_range,
        disabled=False
    )    
    
    # Update function for the Daily Downloads per Platform and call the needed filters
    def update_line_plot(start_date, end_date, start_platform, end_platform, mergeplatforms):
        if mergeplatforms:
            
            # If the "Merge Platforms" checkbox is checked, calculate the total users by date
            filtered_data = filter_data(start_date, end_date, start_platform, end_platform)
            total_data = filtered_data.groupby('daily_date')['users'].sum().reset_index()
            
            # Add image optimal figure sizing and quality for google docs.
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)  
            
            fig = go.Figure()
            fig.add_trace(go.Scatter(
                x=total_data['daily_date'], # X-axis: Daily Dates
                y=total_data['users'],  # Y-axis: Total users for each date
                name='Total' # Legend label for the Total
            ))
        else:
            # If "Merge Platforms" is unchecked, display the data per platform
            filtered_data = filter_data(start_date, end_date, start_platform, end_platform)
        
            # Add image optimal figure sizing and quality for google docs.
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)            
            fig = go.Figure()

            platforms = filtered_data['platform'].unique()
            
            # Loop through each unique platform in the dataset
            for platform in platforms:
                # Filter the data to include only the current platform                
                platform_data = filtered_data[filtered_data['platform'] == platform]
                
                # Group the filtered data by 'daily_date' and calculate the sum of 'users' for each date
                platform_data_grouped = platform_data.groupby('daily_date')['users'].sum().reset_index()
                
                # Add a Scatter plot for the current platform to the figure
                fig.add_trace(go.Scatter(
                    x=platform_data_grouped['daily_date'], # X-axis: Daily Dates
                    y=platform_data_grouped['users'], # Y-axis: Total users for each date
                    name=platform # Legend label for the platform
                ))
        # Insert labels for the title, x-axis, y-axis and define sizing of the image.
        fig.update_layout(
                            title="Daily Downloads per Platform",
                            xaxis_title="Date",
                            yaxis_title="Downloads",
                            width=width_pixels,
                            height=height_pixels,            
                         )

        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_download_platform.html')
        
        # Display the figure
        fig.show()

    # Create an interactive widget to update the Daily Downloads per Platform
    widget = interactive(
        update_line_plot, 
        start_date=start_date_picker, 
        end_date=end_date_picker,
        start_platform=start_platform_range_picker,
        end_platform=end_platform_range_picker,
        mergeplatforms=merge_platforms_checkbox
    )

    # Display the widgets
    display(widget)

# %%
# Create a function to display User Funnel
def display_funnel_users_visualization():
    # Load the dataset
    df = pd.read_csv('../CSV/fulldatadaily.csv')
    
    # Define the default start and end age ranges
    default_start_age_range = 'None'
    default_end_age_range = 'Unknown'

    # Filter out 'Unknown' and NaN values from the age_range column
    filtered_age_ranges = df[df['age_range'].notna() & (df['age_range'] != 'Unknown')]['age_range']

    # Sort the unique age range values with a custom sorting function
    unique_age_ranges = sorted(filtered_age_ranges.unique(), key=lambda x: (float(x.split('-')[0]) if '-' in x else float('inf')))
    
    # Append 'Unknown' and 'None' to the end of the sorted list
    unique_age_ranges.append('Unknown')
    unique_age_ranges.append('None')
    
    # Create Dropdown Widgets for age range filtering options
    start_age_range_picker = widgets.Dropdown(
        description='Start Age Range:',
        options=unique_age_ranges,
        value=default_start_age_range,
        disabled=False
    )
    end_age_range_picker = widgets.Dropdown(
        description='End Age Range:',
        options=unique_age_ranges,
        value=default_end_age_range,
        disabled=False
    )

    # Sort the platform options alphabetically and drop nan values
    platform_options = sorted(df['platform'].dropna().astype(str).unique())

    # Define default start and end platform ranges
    default_start_platform_range = 'android'
    default_end_platform_range = 'web'
    
    # Create Dropdown Widgets for platform filtering options
    start_platform_range_picker = widgets.Dropdown(
        description='Start Platform:',
        options=platform_options,
        value=default_start_platform_range,
        disabled=False
    )
    end_platform_range_picker = widgets.Dropdown(
        description='End Platform:',
        options=platform_options,
        value=default_end_platform_range,
        disabled=False
    )
    # Update function for the User Funnel and call the needed filters
    def display_funnel_users_visualization(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform):
        # Load dataset
        df = pd.read_csv('../CSV/fulldatadaily.csv')
        
        # Transform daily_date into Y-M-D format.
        df['daily_date'] = pd.to_datetime(df['daily_date'], format='%Y-%m-%d')
        start_date = pd.Timestamp(start_date)
        end_date = pd.Timestamp(end_date)

        
        if start_age_range != 'None' and end_age_range != 'None':
            # Check if specific age range filters are applied, and filter the dataset accordingly
            df = df[(df['age_range'] >= start_age_range) & (df['age_range'] <= end_age_range)]
        
        # Apply multiple filters to the dataset:
        # 1. Filter by date range using 'daily_date'
        # 2. Filter by platform range using 'platform'        
        df = df[(df['daily_date'] >= start_date) & (df['daily_date'] <= end_date) &
                (df['platform'] >= start_platform) & (df['platform'] <= end_platform)]
        
        # Perform data aggregation to calculate the number of unique users for each funnel step
        funnel_data = df.groupby(['funnel_step', 'funnel_name', 'platform']).agg({
            'user_ids': 'nunique'
        }).reset_index()
        
        # Define a dictionary to correct the funnel step names
        name_correction_dict = {
            "downloads": "Downloads",
            "signups": "Signups",
            "rides_requested": "Rides Requested",
            "rides_completed": "Rides Completed",
        }        
        
        # Sort the funnel data by 'funnel_step' in descending order
        funnel_data = funnel_data.sort_values(by="funnel_step", ascending=False)
        
        # Apply name corrections to the 'funnel_name' column
        funnel_data['funnel_name'] = funnel_data['funnel_name'].replace(name_correction_dict)        
        
        # Pivot the data for plotting
        pivot_df = funnel_data.pivot(index="funnel_step", columns="platform", values="user_ids")
        pivot_df_names = funnel_data.pivot(index="funnel_step", columns="platform", values="funnel_name")
        
        # Specify colors for each platform
        colors = {
            "android": "rgb(0, 123, 255)",
            "ios": "rgb(40, 167, 69)",
            "web": "rgb(220, 53, 69)",
        }
        
        # Add image optimal figure sizing and quality for google docs.
        figsize_inches =  (10.751, 7.631)
        dpi = 96
        width_pixels = int(figsize_inches[0] * dpi)
        height_pixels = int(figsize_inches[1] * dpi)
        fig = go.Figure()
        
        for platform in pivot_df.columns:
            # Add a Funnel chart trace for each platform
            fig.add_trace(go.Funnel(
                # Add labels to the graphic
                name=platform,
                y=pivot_df_names[platform],
                x=pivot_df[platform],
                textinfo="value+percent initial",
                textposition="inside",
                opacity=0.75,
                marker=dict(color=colors[platform]),
            ))
        
        # Insert labels for the title, x-axis, y-axis and define sizing of the image.            
        fig.update_layout(
            title="User Funnel",
            legend_title="Platform",
            width=width_pixels,
            height=height_pixels,
        )
        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_users_funnel.html')          
        
        # Display the figure
        fig.show()

    # Create an interactive widget to update the funnel chart
    interactive_plot = interactive(
        display_funnel_users_visualization,
        start_date=start_date_picker,
        end_date=end_date_picker,
        start_age_range=start_age_range_picker,
        end_age_range=end_age_range_picker,
        start_platform=start_platform_range_picker,
        end_platform=end_platform_range_picker
    )

    # Display the interactive widget
    output = interactive_plot.children[-1]
    output.layout.height = '400px'
    display(interactive_plot)
  
# Create an output widget for displaying the visualizations
output = widgets.Output()

# %%
# Define a function to display the funnel chart for Rides Funnel
def display_funnel_rides_visualization():
    
    # Load the dataset
    df = pd.read_csv('../CSV/fulldatadaily.csv')

    # Define the default start and end age ranges
    default_start_age_range = '18-24'
    default_end_age_range = 'Unknown'

    # Filter out 'Unknown' and NaN values from the age_range column
    filtered_age_ranges = df[df['age_range'].notna() & (df['age_range'] != 'Unknown')]['age_range']

    # Sort the unique age range values with a custom sorting function
    unique_age_ranges = sorted(filtered_age_ranges.unique(), key=lambda x: (float(x.split('-')[0]) if '-' in x else float('inf')))

    # Append 'Unknown' and 'None' to the end of the sorted list
    unique_age_ranges.append('Unknown')
    unique_age_ranges.append('None')

    start_age_range_picker = widgets.Dropdown(
        description='Start Age Range:',
        options=unique_age_ranges,
        value=default_start_age_range,
        disabled=False
    )

    end_age_range_picker = widgets.Dropdown(
        description='End Age Range:',
        options=unique_age_ranges,
        value=default_end_age_range,
        disabled=False
    )

    # Define the default start and end platform ranges
    default_start_platform_range = 'android'
    default_end_platform_range = 'web'

    # Sort the platform options alphabetically and drop nan values
    platform_options = sorted(df['platform'].dropna().astype(str).unique())
    
    # Create Dropdown Widgets for platform filtering options
    start_platform_range_picker = widgets.Dropdown(
        description='Start Platform:',
        options=platform_options,
        value=default_start_platform_range,
        disabled=False
    )

    end_platform_range_picker = widgets.Dropdown(
        description='End Platform:',
        options=platform_options,
        value=default_end_platform_range,
        disabled=False
    )

    # Update function for the Rides Funnel and call the needed filters
    def display_funnel_rides_visualization(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform):
        # Load dataset
        df = pd.read_csv('../CSV/fulldatadaily.csv')
        
        # Transform daily_date into Y-M-D format.
        df['daily_date'] = pd.to_datetime(df['daily_date'], format='%Y-%m-%d')
        start_date = pd.Timestamp(start_date)
        end_date = pd.Timestamp(end_date)
        
        # Filter the dataset based on funnel steps, date range, age range and platform
        filtered_df = df[
            (df['funnel_step'].isin([3, 4])) & 
            (df['daily_date'] >= pd.Timestamp(start_date)) &
            (df['daily_date'] <= pd.Timestamp(end_date)) &
            ((df['age_range'] >= start_age_range) | (df['age_range'].isna())) &
            ((df['age_range'] <= end_age_range) | (df['age_range'] == 'Unknown')) &
            (df['platform'] >= start_platform) &
            (df['platform'] <= end_platform)
        ]

        # Perform data aggregation to calculate the number of unique users for each funnel step
        funnel_data = filtered_df.groupby(['funnel_step', 'funnel_name', 'platform']).agg({
            'user_ids': 'nunique',  # Count unique user IDs
            'rides': 'sum'  # Sum of rides
        }).reset_index()
        
        # Define a dictionary to correct the funnel step names
        name_correction_dict = {
            "rides_requested": "Rides Requested",
            "rides_completed": "Rides Completed",
        }          
        # Sort the DataFrame by funnel step in ascending order
        funnel_data = funnel_data.sort_values(by="funnel_step")
        
        # Apply name corrections to the 'funnel_name' column
        funnel_data['funnel_name'] = funnel_data['funnel_name'].replace(name_correction_dict) 
        
        # Pivot the data for plotting
        pivot_df = funnel_data.pivot(index="funnel_step", columns="platform", values="rides")
        pivot_df_names = funnel_data.pivot(index="funnel_step", columns="platform", values="funnel_name")

        # Specify colors for each platform
        colors = {
            "android": "rgb(0, 123, 255)",
            "ios": "rgb(40, 167, 69)",
            "web": "rgb(220, 53, 69)",
        }

        # Add image optimal figure sizing and quality for google docs.
        figsize_inches = (10.751, 7.631)
        dpi = 96
        width_pixels = int(figsize_inches[0] * dpi)
        height_pixels = int(figsize_inches[1] * dpi)
        fig = go.Figure()

        # Group the data by platform
        for platform in pivot_df.columns:
            # Add a Funnel chart trace for each platform
            fig.add_trace(go.Funnel(
                # Add labels to the graphic
                name=platform,
                y=pivot_df_names[platform],
                x=pivot_df[platform],
                textinfo="value+percent initial",
                textposition="inside",
                opacity=0.75,
                marker=dict(color=colors[platform]),
            ))

        # Insert labels for the title, x-axis, y-axis and define sizing of the image.
        fig.update_layout(
            title="Rides Funnel",
            legend_title="Platform",
            width=width_pixels,
            height=height_pixels,
        )

        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_rides_funnel.html')  
    
        # Display the figure
        fig.show()

    # Create an interactive widget for the funnel chart
    interactive_funnel = interactive(
        display_funnel_rides_visualization,
        start_date=start_date_picker,
        end_date=end_date_picker,
        start_age_range=start_age_range_picker,
        end_age_range=end_age_range_picker,
        start_platform=start_platform_range_picker,
        end_platform=end_platform_range_picker
    )

    # Display the interactive widget
    display(interactive_funnel)
    
# Create an output widget for displaying the visualizations
output = widgets.Output()

# %%
# Create a function to display Signups by Age Range - Platform
def display_signups_visualization():
    # Load the dataset
    df = pd.read_csv('../CSV/funneldatawithdailydates.csv')
    # Set the funnel step
    df = df[df['funnel_step'] == 2]
    
    # Convert the 'daily_date' column to datetime
    df['daily_date'] = pd.to_datetime(df['daily_date'], format='%Y-%m-%d')

    # Filter the dataset based on the date range, age range, platform
    def filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform):
        start_date = pd.Timestamp(start_date).date()
        end_date = pd.Timestamp(end_date).date()
        filtered_df = df[
            (df['daily_date'].dt.date >= start_date) &
            (df['daily_date'].dt.date <= end_date) &
            (df['age_range'] >= start_age_range) &
            (df['age_range'] <= end_age_range) &
            (df['platform'] >= start_platform) &
            (df['platform'] <= end_platform)
        ]
        return filtered_df
    
    # Filter out 'Unknown' values from the age_range column
    filtered_age_ranges = df[df['age_range'] != 'Unknown']['age_range']

    # Sort the unique age range values with a custom sorting function
    unique_age_ranges = sorted(filtered_age_ranges.unique(), key=lambda x: [int(age) for age in x.split('-')])
    
    # Append 'Unknown' to the end of the sorted list
    unique_age_ranges.append('Unknown')     

    # Define default start and end age ranges
    default_start_age_range = '18-24'
    default_end_age_range = 'Unknown'
    
    # Create Dropdown Widgets for Age Range filtering option    
    start_age_range_picker = widgets.Dropdown(
        description='Start Age Range:',
        options=unique_age_ranges,
        value=default_start_age_range,
        disabled=False
    )
    end_age_range_picker = widgets.Dropdown(
        description='End Age Range:',
        options=unique_age_ranges,
        value=default_end_age_range,
        disabled=False
    )
    
    # Define default start and end platform ranges
    default_start_platform_range = 'android'
    default_end_platform_range = 'web'
    
    # Create Dropdown Widgets for platform filtering option
    start_platform_range_picker = widgets.Dropdown(
        description='Start Platform:',
        options=df['platform'].unique(),
        value=default_start_platform_range,
        disabled=False
    )
    end_platform_range_picker = widgets.Dropdown(
        description='End Platform:',
        options=df['platform'].unique(),
        value=default_end_platform_range,
        disabled=False
    )

    # Update function for the Signups by Age Range - Platform and call the needed filters
    def update_bar_chart(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform, mergeages):
        if mergeages:
            
            # If the "Merge Ages" checkbox is checked, calculate the total users
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            filtered_data = filtered_data.sort_values(by=["age_range", "platform"], ascending=[True, True])            
            total_data = filtered_data.groupby(['platform'])['users'].sum().reset_index()
            
            # Add image optimal figure sizing and quality for google docs.
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)  
            
            fig = go.Figure()
            fig.add_trace(go.Bar(
                x=total_data['platform'], # X-axis: Platform
                y=total_data['users'], # Y-axis: Total users for each Platform
                name='Total' # Legend label for the Total
            ))
        else:
            # If "Merge Ages" is unchecked, display the data per platform
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            filtered_data = filtered_data.sort_values(by=["age_range", "platform"], ascending=[True, True])  
            
            # Add image optimal figure sizing and quality for google docs.
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)            
            fig = go.Figure()
            
            # Filter platform and age range for unique values
            platforms = filtered_data['platform'].unique()
            age_ranges = filtered_data['age_range'].unique()

            for age_range in age_ranges:
                
                # Loop through each unique age range in the dataset
                age_range_data = filtered_data[filtered_data['age_range'] == age_range]
                users_by_platform = []

                for platform in platforms:
                    
                    # Loop through each unique platform in the dataset
                    platform_data = age_range_data[age_range_data['platform'] == platform]
                    users = platform_data['users'].sum()
                    users_by_platform.append(users)

                # Create a label that includes both age_range and platform information
                label = [f'{age_range} - {platform}' for platform in platforms]

                fig.add_trace(go.Bar(
                    x=label, # X-axis: label that includes both age_range and platform
                    y=users_by_platform, # Y-axis: users by platform
                    name=age_range # Legend Label for the age_range
                ))
        
        # Insert labels for the title, x-axis, y-axis and define sizing of the image.
        fig.update_layout(
                            title="Signups by Age Range - Platform",
                            xaxis_title="Age Range - Platform",
                            yaxis_title="Signups",
                            width=width_pixels,
                            height=height_pixels,            
                        )

        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_signups.html')  
        
        # Display the figure
        fig.show()
    
    # Create an interactive widget to update the bar chart
    widget = interactive(
        update_bar_chart, 
        start_date=start_date_picker, 
        end_date=end_date_picker, 
        start_age_range=start_age_range_picker, 
        end_age_range=end_age_range_picker,
        start_platform=start_platform_range_picker,
        end_platform=end_platform_range_picker,
        mergeages=merge_agerange_checkbox
    )

    # Display the widgets
    display(widget)

# %%
# Create a function to display Daily Signups per Platform
def display_signupsdaily_visualization():
    # Load the dataset
    df = pd.read_csv('../CSV/funneldatawithdailydates.csv')
    
    # Set the funnel step
    df = df[df['funnel_step'] == 2]
    
    # Convert the 'daily_date' column to datetime
    df['daily_date'] = pd.to_datetime(df['daily_date'], format='%Y-%m-%d')

    # Filter the dataset based on the date range, age range, and platform
    def filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform):
        start_date = pd.Timestamp(start_date).date()
        end_date = pd.Timestamp(end_date).date()
        filtered_df = df[
        (df['daily_date'].dt.date >= start_date) & 
        (df['daily_date'].dt.date <= end_date) &
        (df['age_range'] >= start_age_range) & 
        (df['age_range'] <= end_age_range) &        
        (df['platform'] >= start_platform) &
        (df['platform'] <= end_platform)
        ]
        return filtered_df

    # Filter out 'Unknown' values from the age_range column
    filtered_age_ranges = df[df['age_range'] != 'Unknown']['age_range']

    # Sort the unique age range values with a custom sorting function
    unique_age_ranges = sorted(filtered_age_ranges.unique(), key=lambda x: [int(age) for age in x.split('-')])
    
    # Append 'Unknown' to the end of the sorted list
    unique_age_ranges.append('Unknown')     

    # Define default start and end age ranges
    default_start_age_range = '18-24'
    default_end_age_range = 'Unknown'
    
    # Create Dropdown Widgets for Age Range filtering option     
    start_age_range_picker = widgets.Dropdown(
        description='Start Age Range:',
        options=unique_age_ranges,
        value=default_start_age_range,
        disabled=False
    )
    end_age_range_picker = widgets.Dropdown(
        description='End Age Range:',
        options=unique_age_ranges,
        value=default_end_age_range,
        disabled=False
    )    
    # Define default start and end platform ranges
    default_start_platform_range = 'android'
    default_end_platform_range = 'web'
    
    # Create Dropdown Widgets for platform filtering option        
    start_platform_range_picker = widgets.Dropdown(
        description='Start Platform:',
        options=df['platform'].unique(),
        value=default_start_platform_range,
        disabled=False
    )
    end_platform_range_picker = widgets.Dropdown(
        description='End Platform:',
        options=df['platform'].unique(),
        value=default_end_platform_range,
        disabled=False
    )

# Update function for the Daily Signups per Platform and call the needed filters
    def update_line_plot(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform, mergeplatforms):
        if mergeplatforms:
        
            # If the "Merge Platforms" checkbox is checked, calculate the total users by date
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            total_data = filtered_data.groupby('daily_date')['users'].sum().reset_index()
            
            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()
            fig.add_trace(go.Scatter(
                x=total_data['daily_date'], # X-axis: Daily dates
                y=total_data['users'], # Y-axis: Total users
                name='Total' # Legend label for the Total
            ))
        else:
        # If "Merge Platforms" is unchecked, display the data per platform
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
             
            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            fig = go.Figure()

            # Filter platform for unique values            
            platforms = filtered_data['platform'].unique()

            for platform in platforms:
                # Loop through each unique platform in the dataset
                platform_data = filtered_data[filtered_data['platform'] == platform]
                # Calculate daily total users grouped by platform_data
                platform_data_grouped = platform_data.groupby('daily_date')['users'].sum().reset_index()

                fig.add_trace(go.Scatter(
                    x=platform_data_grouped['daily_date'], # X-axis: Daily dates
                    y=platform_data_grouped['users'], # Y-axis: Total users
                    name=platform # Legend label for the Platform
                ))
        
        # Insert labels for the title, x-axis, y-axis and define sizing of the image.
        fig.update_layout(
                            title="Daily Signups per Platform",
                            xaxis_title="Date",
                            yaxis_title="Signups",
                            width=width_pixels,
                            height=height_pixels,            
                        )

        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_signups_daily.html')          
        
        # Display the figure        
        fig.show()

    # Create an interactive widget to update the line plot
    widget = interactive(
        update_line_plot, 
        start_date=start_date_picker, 
        end_date=end_date_picker, 
        start_age_range=start_age_range_picker, 
        end_age_range=end_age_range_picker,        
        start_platform=start_platform_range_picker, 
        end_platform=end_platform_range_picker,
        mergeplatforms=merge_platforms_checkbox
    )

    # Display the widgets
    display(widget)

# %%
# Create a function to display Ride Requested Users by Age Range - Platform
def display_user_by_riderequests_visualization():
    # Load the dataset
    df = pd.read_csv('../CSV/fulldatadaily.csv')
    
    # Set the funnel step
    df = df[df['funnel_step'] == 3]
    
    # Convert the 'daily_date' column to datetime
    df['daily_date'] = pd.to_datetime(df['daily_date'], format='%Y-%m-%d')

    # Filter the dataset based on the date range, age range and platform
    def filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform):
        start_date = pd.Timestamp(start_date).date()
        end_date = pd.Timestamp(end_date).date()
        filtered_df = df[
            (df['daily_date'].dt.date >= start_date) &
            (df['daily_date'].dt.date <= end_date) &
            (df['age_range'] >= start_age_range) &
            (df['age_range'] <= end_age_range) &
            (df['platform'] >= start_platform) &
            (df['platform'] <= end_platform)
        ]
        return filtered_df

    # Filter out 'Unknown' values from the age_range column
    filtered_age_ranges = df[df['age_range'] != 'Unknown']['age_range']

    # Sort the unique age range values with a custom sorting function
    unique_age_ranges = sorted(filtered_age_ranges.unique(), key=lambda x: [int(age) for age in x.split('-')])
    
    # Append 'Unknown' to the end of the sorted list
    unique_age_ranges.append('Unknown')     

    # Define default start and end age ranges
    default_start_age_range = '18-24'
    default_end_age_range = 'Unknown'
    
    # Create Dropdown Widgets for Age Range filtering option     
    start_age_range_picker = widgets.Dropdown(
        description='Start Age Range:',
        options=unique_age_ranges,
        value=default_start_age_range,
        disabled=False
    )
    end_age_range_picker = widgets.Dropdown(
        description='End Age Range:',
        options=unique_age_ranges,
        value=default_end_age_range,
        disabled=False
    )
    # Define default start and end platform ranges
    default_start_platform_range = 'android'
    default_end_platform_range = 'web'
    
    #Get unique platform options and sort them
    platform_options = sorted(df['platform'].dropna().astype(str).unique())

    # Create Dropdown Widgets for platform filtering option     
    start_platform_range_picker = widgets.Dropdown(
        description='Start Platform:',
        options=platform_options,
        value=default_start_platform_range,
        disabled=False
    )
    end_platform_range_picker = widgets.Dropdown(
        description='End Platform:',
        options=platform_options,
        value=default_end_platform_range,
        disabled=False
    )
    # Update function for the Ride Requested Users by Age Range - Platform and call the needed filters
    def update_bar_chart(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform, mergeages):
        if mergeages:
            # If the "Merge Ages" checkbox is checked, calculate the total users
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            
            # Sort by age range and platform
            filtered_data = filtered_data.sort_values(by=["age_range", "platform"], ascending=[True, True])


            # Define a custom aggregation function to count unique values
            def unique_count(series):
                return series.nunique()
            
            total_data = filtered_data.groupby(['platform']).agg({
                'user_ids': unique_count,
                'rides': 'sum'
            }).reset_index()            

            # Add image optimal figure sizing and quality for google docs.
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()
            fig.add_trace(go.Bar(
                x=total_data['platform'], # X-axis: Platform
                y=total_data['user_ids'], # Y-axis: Total users
                name='Total Users' # Legend label for the Total users
            ))
        else:
            # If "Merge Ages" is unchecked, display the data per platform
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            
            # Sort data by age_range and platform
            filtered_data = filtered_data.sort_values(by=["age_range", "platform"], ascending=[True, True])           
            
            # Add image optimal figure sizing and quality for google docs.
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()
            
            # Filter platform and age range for unique values 
            platforms = filtered_data['platform'].unique()
            age_ranges = filtered_data['age_range'].unique()

            for age_range in age_ranges:
                # Loop through each unique age range in the dataset
                age_range_data = filtered_data[filtered_data['age_range'] == age_range]
                users_by_platform = []

                for platform in platforms:
                    
                    # Calculate and store unique user counts for each platform in the dataset
                    platform_data = age_range_data[age_range_data['platform'] == platform]
                    unique_users = platform_data['user_ids'].nunique()
                    users_by_platform.append(unique_users)

                # Create a label that includes both age_range and platform information
                label = [f'{age_range} - {platform}' for platform in platforms]

                fig.add_trace(go.Bar(x=label, y=users_by_platform, name=age_range))
        
        # Insert labels for the title, x-axis, y-axis and define sizing of the image.
        fig.update_layout(
                            title="Ride Requested Users by Age Range - Platform",
                            xaxis_title="Age Range - Platform",
                            yaxis_title="Users",
                            width=width_pixels,
                            height=height_pixels,
                        )

        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_users_by_rides_requested.html')  
        
        # Display the figure         
        fig.show()
        
    # Create an interactive widget to update the bar chart
    widget = interactive(
        update_bar_chart, 
        start_date=start_date_picker, 
        end_date=end_date_picker, 
        start_age_range=start_age_range_picker, 
        end_age_range=end_age_range_picker,
        start_platform=start_platform_range_picker,
        end_platform=end_platform_range_picker,
        mergeages=merge_agerange_checkbox
    )

    # Display the widgets
    display(widget)

# %%
# Create a function to display Rides Requested by Age Range - Platform
def display_riderequests_visualization():
    # Load the dataset
    df = pd.read_csv('../CSV/funneldatawithdailydates.csv')

    # Set the funnel step
    df = df[df['funnel_step'] == 3]
    
    # Convert the 'daily_date' column to datetime
    df['daily_date'] = pd.to_datetime(df['daily_date'], format='%Y-%m-%d')

    # Filter the dataset based on the date range, age range and platform
    def filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform):
        start_date = pd.Timestamp(start_date).date()
        end_date = pd.Timestamp(end_date).date()
        filtered_df = df[
            (df['daily_date'].dt.date >= start_date) &
            (df['daily_date'].dt.date <= end_date) &
            (df['age_range'] >= start_age_range) &
            (df['age_range'] <= end_age_range) &
            (df['platform'] >= start_platform) &
            (df['platform'] <= end_platform)
        ]
        return filtered_df

    # Filter out 'Unknown' values from the age_range column
    filtered_age_ranges = df[df['age_range'] != 'Unknown']['age_range']

    # Sort the unique age range values with a custom sorting function
    unique_age_ranges = sorted(filtered_age_ranges.unique(), key=lambda x: [int(age) for age in x.split('-')])
    # Append 'Unknown' to the end of the sorted list
    unique_age_ranges.append('Unknown')     

    # Define default start and end age ranges
    default_start_age_range = '18-24'
    default_end_age_range = 'Unknown'

    # Create Dropdown Widgets for Age Range filtering option 
    start_age_range_picker = widgets.Dropdown(
        description='Start Age Range:',
        options=unique_age_ranges,
        value=default_start_age_range,
        disabled=False
    )
    end_age_range_picker = widgets.Dropdown(
        description='End Age Range:',
        options=unique_age_ranges,
        value=default_end_age_range,
        disabled=False
    )
    # Define default start and end platform ranges
    default_start_platform_range = 'android'
    default_end_platform_range = 'web'
    
    #Get unique platform options, sort them and drop NaN values
    platform_options = sorted(df['platform'].dropna().astype(str).unique())

    # Create Dropdown Widgets for platform filtering option    
    start_platform_range_picker = widgets.Dropdown(
        description='Start Platform:',
        options=platform_options,
        value=default_start_platform_range,
        disabled=False
    )
    end_platform_range_picker = widgets.Dropdown(
        description='End Platform:',
        options=platform_options,
        value=default_end_platform_range,
        disabled=False
    )
    # Update function for the Rides Requested by Age Range - Platform and call needed filters
    def update_bar_chart(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform, mergeages):
        if mergeages:
            # If the "Merge Ages" checkbox is checked, calculate the total users
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            filtered_data = filtered_data.sort_values(by=["age_range", "platform"], ascending=[True, True])
            total_data = filtered_data.groupby(['platform'])['rides'].sum().reset_index()
            
            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()
            fig.add_trace(go.Bar(
                x=total_data['platform'], # X-axis: Platform
                y=total_data['rides'], # Y-axis: Rides
                name='Total' # Legend label for Total
            ))
        else:
            # If "Merge Ages" is unchecked, display the data per platform
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            filtered_data = filtered_data.sort_values(by=["age_range", "platform"], ascending=[True, True])

            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()
            
            # Filter platform and age range for unique values
            platforms = filtered_data['platform'].unique()
            age_ranges = filtered_data['age_range'].unique()

            for age_range in age_ranges:
                # Loop through each unique age range in the dataset
                age_range_data = filtered_data[filtered_data['age_range'] == age_range]
                rides_by_platform = []

                for platform in platforms:

                    # Calculate and store total rides for each platform in the dataset
                    platform_data = age_range_data[age_range_data['platform'] == platform]
                    rides = platform_data['rides'].sum()
                    rides_by_platform.append(rides)

                # Create a label that includes both age_range and platform information
                label = [f'{age_range} - {platform}' for platform in platforms]

                fig.add_trace(go.Bar(
                    x=label, # X-axis: Label that includes age range and platform
                    y=rides_by_platform, # Y-axis: Total rides for each platform
                    name=age_range # Legend label for the age range
                ))

        # Insert labels for the title, x-axis, y-axis and define sizing of the image.        
        fig.update_layout(
                            title="Rides Requested by Age Range - Platform",
                            xaxis_title="Age Range - Platform",
                            yaxis_title="Rides Requested",
                            width=width_pixels,
                            height=height_pixels,
                        )

        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_ride_requests.html')  
        
        # Display the figure
        fig.show()
    
    # Create an interactive widget to update the bar chart
    widget = interactive(
        update_bar_chart, 
        start_date=start_date_picker, 
        end_date=end_date_picker, 
        start_age_range=start_age_range_picker, 
        end_age_range=end_age_range_picker,
        start_platform=start_platform_range_picker,
        end_platform=end_platform_range_picker,
        mergeages=merge_agerange_checkbox
    )

    # Display the widgets
    display(widget)

# %%
# Create a function to display Daily Rides & Cancellations per Platform
def display_rides_cancellations_visualization():
    # Load the dataset
    df = pd.read_csv('../CSV/funneldatawithdailydates.csv')
    # Set the funnel step
    df = df[df['funnel_step'] == 3]
    
    # Convert the 'daily_date' column to datetime
    df['daily_date'] = pd.to_datetime(df['daily_date'], format='%Y-%m-%d')

    # Filter the dataset based on the date range, age range and platform
    def filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform):
        start_date = pd.Timestamp(start_date).date()
        end_date = pd.Timestamp(end_date).date()
        filtered_df = df[
        (df['daily_date'].dt.date >= start_date) & 
        (df['daily_date'].dt.date <= end_date) &
        (df['age_range'] >= start_age_range) & 
        (df['age_range'] <= end_age_range) &        
        (df['platform'] >= start_platform) &
        (df['platform'] <= end_platform)
        ]
        return filtered_df
    
    # Filter out 'Unknown' values from the age_range column
    filtered_age_ranges = df[df['age_range'] != 'Unknown']['age_range']

    # Sort the unique age range values with a custom sorting function
    unique_age_ranges = sorted(filtered_age_ranges.unique(), key=lambda x: [int(age) for age in x.split('-')])
    
    # Append 'Unknown' to the end of the sorted list
    unique_age_ranges.append('Unknown')     

    # Define default start and end age ranges
    default_start_age_range = '18-24'
    default_end_age_range = 'Unknown'
    
    # Create Dropdown Widgets for Age Range filtering option    
    start_age_range_picker = widgets.Dropdown(
        description='Start Age Range:',
        options=unique_age_ranges,
        value=default_start_age_range,
        disabled=False
    )
    end_age_range_picker = widgets.Dropdown(
        description='End Age Range:',
        options=unique_age_ranges,
        value=default_end_age_range,
        disabled=False
    )    
    # Define default start and end platform ranges
    default_start_platform_range = 'android'
    default_end_platform_range = 'web'
    
    #Sort platform and drop nan values
    platform_options = sorted(df['platform'].dropna().astype(str).unique())        
    
    # Create Dropdown Widgets for platform filtering option     
    start_platform_range_picker = widgets.Dropdown(
        description='Start Platform:',
        options=platform_options,
        value=default_start_platform_range,
        disabled=False
    )
    end_platform_range_picker = widgets.Dropdown(
        description='End Platform:',
        options=platform_options,
        value=default_end_platform_range,
        disabled=False
    )

    # Update function for the Daily Rides & Cancellations per Platform and call the needed filters
    def update_line_plot(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform, mergeplatforms):
        if mergeplatforms:
            
            # If the "Merge Platforms" checkbox is checked, calculate the total rides and cancellations
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            filtered_data = filtered_data.sort_values(by="platform", ascending=True)
            total_rides = filtered_data.groupby('daily_date')['rides'].sum().reset_index()
            total_cancellations = filtered_data.groupby('daily_date')['cancellations'].sum().reset_index()

            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()
            fig.add_trace(go.Scatter(
                x=total_rides['daily_date'], # X-axis: Daily dates
                y=total_rides['rides'], # Y-axis: Total Rides
                name='Rides' # Legend label for Rides
            ))
            fig.add_trace(go.Scatter(
                x=total_cancellations['daily_date'], # X-axis: Daily dates
                y=total_cancellations['cancellations'], # Y-axis: Cancellations
                name='Cancellations' # Legend label for Cancellations
            ))
        else:
            # If "Merge Platforms" is unchecked, display the data per platform
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            
            # Sort the data by platform
            filtered_data = filtered_data.sort_values(by="platform", ascending=True)
            
            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()

            # Filter platform unique values
            platforms = filtered_data['platform'].unique()
        
            for platform in platforms:
                # Calculate and store daily total rides and cancellations grouped by daily date for each platform
                platform_data = filtered_data[filtered_data['platform'] == platform]
                platform_data_grouped = platform_data.groupby('daily_date')[['rides', 'cancellations']].sum().reset_index()
                fig.add_trace(go.Scatter(
                    x=platform_data_grouped['daily_date'], # X-axis: Daily dates
                    y=platform_data_grouped['rides'], # Y-axis: Total Rides
                    name=f'{platform} Rides' # Legend label name for the platform and Rides
                ))
                fig.add_trace(go.Scatter(
                    x=platform_data_grouped['daily_date'], # X-axis: Daily dates
                    y=platform_data_grouped['cancellations'], # Y-axis: Total Cancellations
                    name=f'{platform} Cancellations' # Legend label name for the platform and Cancellations
                ))

        # Insert labels for the title, x-axis, y-axis and define sizing of the image.
        fig.update_layout(
                            title="Daily Rides & Cancellations per Platform",
                            xaxis_title="Date",
                            yaxis_title="Count",
                            width=width_pixels,
                            height=height_pixels,
                         )
    
         # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_rides_cancellations.html')             

        # Display the figure
        fig.show()

    # Create an interactive widget to update the line plot
    widget = interactive(
        update_line_plot, 
        start_date=start_date_picker, 
        end_date=end_date_picker, 
        start_age_range=start_age_range_picker, 
        end_age_range=end_age_range_picker,        
        start_platform=start_platform_range_picker, 
        end_platform=end_platform_range_picker,
        mergeplatforms=merge_platforms_checkbox
    )

    # Display the widgets
    display(widget)

# %%
# Create a function to display Surge-Pricing
def display_surge_pricing():
    # Load the dataset from the CSV file
    df = pd.read_csv('../CSV/surge_pricing.csv')
    
    # Calculate the width and height in pixels based on the desired figsize in inches and DPI
    figsize_inches = (8.27, 5.87)
    dpi = 96
    width_pixels = int(figsize_inches[0] * dpi)
    height_pixels = int(figsize_inches[1] * dpi)

    fig = go.Figure()
    
    # Define the unique requests values
    hours = df['request_hour']
    num_requests = df['num_requests']

    fig.add_trace(go.Bar(
        x=hours, # X-axis: Hours
        y=num_requests, # Y-axis: Number of Requests
        hoverinfo='x+y', # Mouse Hover information combined between x and y
        text=num_requests, # Text labels for each bar
        textposition='auto', # Auto position the text
        marker=dict(color='blue') # Set the bar color to blue
    ))

    # Insert labels for the title, x-axis, y-axis and define sizing of the image.
    fig.update_layout(
        title='Surge-Pricing',
        xaxis_title='Hour',
        yaxis_title='Ride Requests',
        xaxis=dict(dtick=1),
        showlegend=False,
        width=width_pixels,
        height=height_pixels
    )

    # Transform the interactive Plotly chart into an Html and save it.
    fig.write_html('../InteractiveGraphics/interactive_surge_pricing.html')
    
    # Display the figure
    fig.show()

# %%
# Create a function to display Minimum Rides Per User
def display_minridesperuser():
    # Load the dataset from the CSV file
    df = pd.read_csv('../CSV/minridesperuser.csv')

    # Add image optimal figure sizing and quality for google docs.    
    figsize_inches = (8.27, 5.87)
    dpi = 96
    width_pixels = int(figsize_inches[0] * dpi)
    height_pixels = int(figsize_inches[1] * dpi)
    
    fig = go.Figure()

    # Define the unique charge_status values and bin ranges
    user_statuses = df['user_id'].unique()
    bins = list(range(0, 61, 5))

    # Create a list to store the counts of unique users for each 'rides' range
    user_counts = []

    for bin_start, bin_end in zip(bins[:-1], bins[1:]):
        # Calculate the number of unique users falling within the currennt rides bin
        user_count = df[(df['rides'] >= bin_start) & (df['rides'] < bin_end)]['user_id'].nunique()
        user_counts.append(user_count)

    fig.add_trace(go.Bar(
        x=[f"{bin_start}-{bin_end}" for bin_start, bin_end in zip(bins[:-1], bins[1:])], # X-axis: Intervals defined by bins 
        y=user_counts, # Y-axis: Total Users
        hoverinfo='x+y', # Mouse Hover information combined between x and y
        text=user_counts, # Text Labels for each bar
        textposition='auto', # Auto position the text
    ))

    # Insert labels for the title, x-axis, y-axis and define sizing of the image.
    fig.update_layout(
        title='Minimum Rides Per User',
        xaxis_title='Number of Rides(Range)',
        yaxis_title='Number of Users',
        barmode='group',
        width=width_pixels,
        height=height_pixels,        
    )
    # Transform the interactive Plotly chart into an Html and save it.
    fig.write_html('../InteractiveGraphics/interactive_minridesperuser.html')
    
    # Display the figure
    fig.show()

# %%
# Create a function to display Rides Completed Users by Age Range - Platform
def display_user_by_ridecompletes_visualization():
    # Load the dataset
    df = pd.read_csv('../CSV/fulldatadaily.csv')
    
    # Set the funnel step
    df = df[df['funnel_step'] == 4]
    
    # Convert the 'daily_date' column to datetime
    df['daily_date'] = pd.to_datetime(df['daily_date'], format='%Y-%m-%d')

    # Filter the dataset based on the date range, age range and platform
    def filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform):
        start_date = pd.Timestamp(start_date).date()
        end_date = pd.Timestamp(end_date).date()
        filtered_df = df[
            (df['daily_date'].dt.date >= start_date) &
            (df['daily_date'].dt.date <= end_date) &
            (df['age_range'] >= start_age_range) &
            (df['age_range'] <= end_age_range) &
            (df['platform'] >= start_platform) &
            (df['platform'] <= end_platform)
        ]
        return filtered_df

    # Filter out 'Unknown' values from the age_range column
    filtered_age_ranges = df[df['age_range'] != 'Unknown']['age_range']

    # Sort the unique age range values with a custom sorting function
    unique_age_ranges = sorted(filtered_age_ranges.unique(), key=lambda x: [int(age) for age in x.split('-')])
    
    # Append 'Unknown' to the end of the sorted list
    unique_age_ranges.append('Unknown')     

    # Define default start and end age ranges
    default_start_age_range = '18-24'
    default_end_age_range = 'Unknown'
    
    # Create Dropdown Widgets for Age Range filtering option    
    start_age_range_picker = widgets.Dropdown(
        description='Start Age Range:',
        options=unique_age_ranges,
        value=default_start_age_range,
        disabled=False
    )
    end_age_range_picker = widgets.Dropdown(
        description='End Age Range:',
        options=unique_age_ranges,
        value=default_end_age_range,
        disabled=False
    )
    # Define default start and end platform ranges
    default_start_platform_range = 'android'
    default_end_platform_range = 'web'
    
    # Get unique platform options, filter out NaN values and sort them
    platform_options = sorted(df['platform'].dropna().astype(str).unique())
    
    # Create Dropdown Widgets for Platform filtering option    
    start_platform_range_picker = widgets.Dropdown(
        description='Start Platform:',
        options=platform_options,
        value=default_start_platform_range,
        disabled=False
    )
    end_platform_range_picker = widgets.Dropdown(
        description='End Platform:',
        options=platform_options,
        value=default_end_platform_range,
        disabled=False
    )
    # Update function to display Rides Completed Users by Age Range - Platform and call needed filters
    def update_bar_chart(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform, mergeages):
        if mergeages:
            # If the "Merge Ages" checkbox is checked, calculate the total users
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            # Sort by age range and platform 
            filtered_data = filtered_data.sort_values(by=["age_range", "platform"], ascending=[True, True])


            # Define a custom aggregation function to count unique values
            def unique_count(series):
                return series.nunique()

            total_data = filtered_data.groupby(['platform']).agg({
                'user_ids': unique_count,
                'rides': 'sum'
            }).reset_index()            
            
            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()
            fig.add_trace(go.Bar(
                x=total_data['platform'], # X-axis: Platform
                y=total_data['user_ids'], # Y-axis: Total users
                name='Total Users' # Legend label for Total Users
            ))
        else:
            # If "Merge Ages" is unchecked, display the data per Age range and platform
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            
            # Sort by age range and platform
            filtered_data = filtered_data.sort_values(by=["age_range", "platform"], ascending=[True, True])           

            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()

            # Filter platform and age range for unique values
            platforms = filtered_data['platform'].unique()
            age_ranges = filtered_data['age_range'].unique()

            for age_range in age_ranges:
                # Loop through each unique age range in the dataset                
                age_range_data = filtered_data[filtered_data['age_range'] == age_range]
                users_by_platform = []

                for platform in platforms:
                    
                    #Calculate and store unique user counts for each platform in the dataset
                    platform_data = age_range_data[age_range_data['platform'] == platform]
                    unique_users = platform_data['user_ids'].nunique()
                    users_by_platform.append(unique_users)

                # Create a label that includes both age_range and platform information
                label = [f'{age_range} - {platform}' for platform in platforms]

                fig.add_trace(go.Bar(
                    x=label, # X-axis: Combined label for age range and platform
                    y=users_by_platform, # Y-axis: Users by Platform
                    name=age_range # Legend label for Age Range
                ))

        # Insert labels for the title, x-axis, y-axis and define sizing of the image.        
        fig.update_layout(
                            title="Rides Completed Users by Age Range - Platform",
                            xaxis_title="Age Range - Platform",
                            yaxis_title="Users",
                            width=width_pixels,
                            height=height_pixels,
                        )

        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_users_by_rides_completed.html')  
        
        # Display the figure
        fig.show()
    
    # Create an interactive widget to update the bar chart
    widget = interactive(
        update_bar_chart, 
        start_date=start_date_picker, 
        end_date=end_date_picker, 
        start_age_range=start_age_range_picker, 
        end_age_range=end_age_range_picker,
        start_platform=start_platform_range_picker,
        end_platform=end_platform_range_picker,
        mergeages=merge_agerange_checkbox
    )

    # Display the widgets
    display(widget)

# %%
# Create a function to display Rides Completed by Age Range - Platform
def display_completed_age_platform():
    # Load the dataset
    df = pd.read_csv('../CSV/funneldatawithdailydates.csv')
    
    # Set the funnel step
    df = df[df['funnel_step'] == 4]
    
    # Convert the 'daily_date' column to datetime
    df['daily_date'] = pd.to_datetime(df['daily_date'], format='%Y-%m-%d')

    # Filter the dataset based on the date range, age range and platform
    def filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform):
        start_date = pd.Timestamp(start_date).date()
        end_date = pd.Timestamp(end_date).date()
        filtered_df = df[
            (df['daily_date'].dt.date >= start_date) &
            (df['daily_date'].dt.date <= end_date) &
            (df['age_range'] >= start_age_range) &
            (df['age_range'] <= end_age_range) &
            (df['platform'] >= start_platform) &
            (df['platform'] <= end_platform)
        ]
        return filtered_df

    # Filter out 'Unknown' values from the age_range column
    filtered_age_ranges = df[df['age_range'] != 'Unknown']['age_range']

    # Sort the unique age range values with a custom sorting function
    unique_age_ranges = sorted(filtered_age_ranges.unique(), key=lambda x: [int(age) for age in x.split('-')])
    
    # Append 'Unknown' to the end of the sorted list
    unique_age_ranges.append('Unknown')     

    # Define default start and end age ranges
    default_start_age_range = '18-24'
    default_end_age_range = 'Unknown'
    
    # Create Dropdown Widgets for age range filtering option    
    start_age_range_picker = widgets.Dropdown(
        description='Start Age Range:',
        options=unique_age_ranges,
        value=default_start_age_range,
        disabled=False
    )
    end_age_range_picker = widgets.Dropdown(
        description='End Age Range:',
        options=unique_age_ranges,
        value=default_end_age_range,
        disabled=False
    )
    # Define default start and end platform ranges
    default_start_platform_range = 'android'
    default_end_platform_range = 'web'

    #Sort platform and drop nan values
    platform_options = sorted(df['platform'].dropna().astype(str).unique())    
    
    # Create Dropdown Widgets for platform filtering option    
    start_platform_range_picker = widgets.Dropdown(
        description='Start Platform:',
        options=platform_options,
        value=default_start_platform_range,
        disabled=False
    )
    end_platform_range_picker = widgets.Dropdown(
        description='End Platform:',
        options=platform_options,
        value=default_end_platform_range,
        disabled=False
    )
    # Update function for the Rides Completed by Age Range - Platform and call needed filters
    def update_bar_chart(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform, mergeages):
        if mergeages:
            # If the "Merge Ages" checkbox is checked, calculate the total users
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            
            # Sort by age range and platform
            filtered_data = filtered_data.sort_values(by=["age_range", "platform"], ascending=[True, True])
            total_data = filtered_data.groupby(['platform'])['rides'].sum().reset_index()

            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()
            fig.add_trace(go.Bar(
                x=total_data['platform'], # X-axis: Platform
                y=total_data['rides'], # Y-axis: Total Rides
                name='Total' # Legend label for Total
            ))
        else:
            # If "Merge" is unchecked, display the data per platform
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            
            # Sort by age range and platform
            filtered_data = filtered_data.sort_values(by=["age_range", "platform"], ascending=[True, True])

            # Add image optimal figure sizing and quality for google docs.             
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()

            # Filter platform and age range for unique values
            platforms = filtered_data['platform'].unique()
            age_ranges = filtered_data['age_range'].unique()

            for age_range in age_ranges:
                # Loop through each unique age range in the dataset
                age_range_data = filtered_data[filtered_data['age_range'] == age_range]
                rides_by_platform = []

                for platform in platforms:
                    # Calculate and store total rides for each platform in the dataset
                    platform_data = age_range_data[age_range_data['platform'] == platform]
                    rides = platform_data['rides'].sum()
                    rides_by_platform.append(rides)

                # Create a label that includes both age_range and platform information
                label = [f'{age_range} - {platform}' for platform in platforms]

                fig.add_trace(go.Bar(
                    x=label, # X-axis: Combined label for age range and platform
                    y=rides_by_platform, # Y-axis: Rides by Platform
                    name=age_range # Legend label for Age Range
                ))

        # Insert labels for the title, x-axis, y-axis and define sizing of the image.        
        fig.update_layout(
                            title="Rides Completed by Age Range - Platform",
                            xaxis_title="Age Range - Platform",
                            yaxis_title="Rides",
                            width=width_pixels,
                            height=height_pixels,            
                         )

        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_completed_age_platform.html')         

        # Display the figure
        fig.show()
    
    # Create an interactive widget to update the bar chart
    widget = interactive(
        update_bar_chart, 
        start_date=start_date_picker, 
        end_date=end_date_picker, 
        start_age_range=start_age_range_picker, 
        end_age_range=end_age_range_picker,
        start_platform=start_platform_range_picker,
        end_platform=end_platform_range_picker,
        mergeages=merge_agerange_checkbox
    )

    # Display the widgets
    display(widget)

# %%
# Create a function to display USD by Age Range - Platform
def display_completed_usd():
    # Load the dataset
    df = pd.read_csv('../CSV/funneldatawithdailydates.csv')
    # Set the funnel step
    df = df[df['funnel_step'] == 4]
    
    # Convert the 'daily_date' column to datetime
    df['daily_date'] = pd.to_datetime(df['daily_date'], format='%Y-%m-%d')

    # Filter the dataset based on the date range, age range and platform
    def filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform):
        start_date = pd.Timestamp(start_date).date()
        end_date = pd.Timestamp(end_date).date()
        filtered_df = df[
            (df['daily_date'].dt.date >= start_date) &
            (df['daily_date'].dt.date <= end_date) &
            (df['age_range'] >= start_age_range) &
            (df['age_range'] <= end_age_range) &
            (df['platform'] >= start_platform) &
            (df['platform'] <= end_platform)
        ]
        return filtered_df
  
    # Filter out 'Unknown' values from the age_range column
    filtered_age_ranges = df[df['age_range'] != 'Unknown']['age_range']

    # Sort the unique age range values with a custom sorting function
    unique_age_ranges = sorted(filtered_age_ranges.unique(), key=lambda x: [int(age) for age in x.split('-')])
    
    # Append 'Unknown' to the end of the sorted list
    unique_age_ranges.append('Unknown')     

    # Define default start and end age ranges
    default_start_age_range = '18-24'
    default_end_age_range = 'Unknown'
    
    # Create Dropdown Widgets for Age Range filtering option    
    start_age_range_picker = widgets.Dropdown(
        description='Start Age Range:',
        options=unique_age_ranges,
        value=default_start_age_range,
        disabled=False
    )
    end_age_range_picker = widgets.Dropdown(
        description='End Age Range:',
        options=unique_age_ranges,
        value=default_end_age_range,
        disabled=False
    )
    # Define default start and end platform ranges
    default_start_platform_range = 'android'
    default_end_platform_range = 'web'
    
    #Sort platform, drop nan values and set to string
    platform_options = sorted(df['platform'].dropna().astype(str).unique())  
    
    # Create Dropdown Widgets for Platform filtering option    
    start_platform_range_picker = widgets.Dropdown(
        description='Start Platform:',
        options=platform_options,
        value=default_start_platform_range,
        disabled=False
    )
    end_platform_range_picker = widgets.Dropdown(
        description='End Platform:',
        options=platform_options,
        value=default_end_platform_range,
        disabled=False
    )

    # Update function for the USD by Age Range - Platform and call needed filters
    def update_bar_chart(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform, mergeages):
        if mergeages:
            # If the "Merge Ages" checkbox is checked, calculate the total users
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            # Sort by age range and platform
            filtered_data = filtered_data.sort_values(by=["age_range", "platform"], ascending=[True, True])
        
            total_data = filtered_data.groupby(['platform'])['total_usd'].sum().reset_index()

            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()
            fig.add_trace(go.Bar(
                x=total_data['platform'], # X-axis: Platforms
                y=total_data['total_usd'], # Y-axis: Total USD
                name='USD' # Legend label for USD
            ))
        else:
            # If "Merge Ages" is unchecked, display the data per platform
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            # Sort by age range and platform
            filtered_data = filtered_data.sort_values(by=["age_range", "platform"], ascending=[True, True])

            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()

            # Filter platform and age range for unique values
            platforms = filtered_data['platform'].unique()
            age_ranges = filtered_data['age_range'].unique()

            for age_range in age_ranges:
                # Loop through each unique age range in the dataset
                age_range_data = filtered_data[filtered_data['age_range'] == age_range]
                usd_by_platform = []

                for platform in platforms:
                    # Calculate and store total USD for each platform in the dataset
                    platform_data = age_range_data[age_range_data['platform'] == platform]
                    usd = platform_data['total_usd'].sum()
                    usd_by_platform.append(usd)

                # Create a label that includes both age_range and platform information
                label = [f'{age_range} - {platform}' for platform in platforms]

                fig.add_trace(go.Bar(
                    x=label, # X-axis: Combined label for age range and platform
                    y=usd_by_platform, # Y-axis: USD by Platform
                    name=age_range # Legend label for Age Range
                ))

        fig.update_layout(
                            title="USD by Age Range - Platform",
                            xaxis_title="Age Range - Platform",
                            yaxis_title="USD",
                            width=width_pixels,
                            height=height_pixels,            
                         )

        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_completed_usd.html')            
        
        # Display the figure
        fig.show()
    
    # Create an interactive widget to update the bar chart
    widget = interactive(
        update_bar_chart, 
        start_date=start_date_picker, 
        end_date=end_date_picker, 
        start_age_range=start_age_range_picker, 
        end_age_range=end_age_range_picker,
        start_platform=start_platform_range_picker,
        end_platform=end_platform_range_picker,
        mergeages=merge_agerange_checkbox
    )

    # Display the widgets
    display(widget)

# %%
# Create a function to display Daily Rides - USD by Platform
def display_completed_usd_daily():
    # Load the dataset
    df = pd.read_csv('../CSV/funneldatawithdailydates.csv')
    # Set funnel step 
    df = df[df['funnel_step'] == 4]
    
    # Convert the 'daily_date' column to datetime
    df['daily_date'] = pd.to_datetime(df['daily_date'], format='%Y-%m-%d')

    # Filter the dataset based on the date range, age range and platform
    def filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform):
        start_date = pd.Timestamp(start_date).date()
        end_date = pd.Timestamp(end_date).date()
        filtered_df = df[
        (df['daily_date'].dt.date >= start_date) & 
        (df['daily_date'].dt.date <= end_date) &
        (df['age_range'] >= start_age_range) & 
        (df['age_range'] <= end_age_range) &        
        (df['platform'] >= start_platform) &
        (df['platform'] <= end_platform)
        ]
        return filtered_df

    # Filter out 'Unknown' values from the age_range column
    filtered_age_ranges = df[df['age_range'] != 'Unknown']['age_range']

    # Sort the unique age range values with a custom sorting function
    unique_age_ranges = sorted(filtered_age_ranges.unique(), key=lambda x: [int(age) for age in x.split('-')])
    
    # Append 'Unknown' to the end of the sorted list
    unique_age_ranges.append('Unknown')     

    # Define default start and end age ranges
    default_start_age_range = '18-24'
    default_end_age_range = 'Unknown'
    
    # Create Dropdown Widgets for age range filtering option    
    start_age_range_picker = widgets.Dropdown(
        description='Start Age Range:',
        options=unique_age_ranges,
        value=default_start_age_range,
        disabled=False
    )
    end_age_range_picker = widgets.Dropdown(
        description='End Age Range:',
        options=unique_age_ranges,
        value=default_end_age_range,
        disabled=False
    )    
    # Define default start and end platform ranges
    default_start_platform_range = 'android'
    default_end_platform_range = 'web'

    platform_options = sorted(df['platform'].dropna().astype(str).unique())  
    
    # Create Dropdown Widgets for Platform filtering option    
    start_platform_range_picker = widgets.Dropdown(
        description='Start Platform:',
        options=platform_options,
        value=default_start_platform_range,
        disabled=False
    )
    end_platform_range_picker = widgets.Dropdown(
        description='End Platform:',
        options=platform_options,
        value=default_end_platform_range,
        disabled=False
    )

    # Update function for Daily Rides - USD by Platform and call needed filters 
    def update_line_plot(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform, mergeplatforms):
        if mergeplatforms:
            # If the "Merge Platforms" checkbox is checked, calculate the total rides and cancellations
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            # Sort by platform
            filtered_data = filtered_data.sort_values(by="platform", ascending=True)            
            total_rides = filtered_data.groupby('daily_date')['rides'].sum().reset_index()
            total_usd = filtered_data.groupby('daily_date')['total_usd'].sum().reset_index()

            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()
            fig.add_trace(go.Scatter(
                x=total_rides['daily_date'], # X-axis: Daily dates
                y=total_rides['rides'], # Y-axis: Total Rides
                name='Rides' # legend label for Rides
            ))
            fig.add_trace(go.Scatter(
                x=total_usd['daily_date'], # X-axis: Daily dates
                y=total_usd['total_usd'], # Y-axis: Total USD
                name='USD' # Legend label for USD
            ))
        else:
            # If "Merge Platforms" is unchecked, display the data per platform
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            # Sort by platform
            filtered_data = filtered_data.sort_values(by="platform", ascending=True)

            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()

            # Filter platform for unique values
            platforms = filtered_data['platform'].unique()
        
            for platform in platforms:
                # Calculate and store total rides and usd for each platform in the dataset
                platform_data = filtered_data[filtered_data['platform'] == platform]
                platform_data_grouped = platform_data.groupby('daily_date')[['rides', 'total_usd']].sum().reset_index()
                fig.add_trace(go.Scatter(
                    x=platform_data_grouped['daily_date'], # X-axis: Daily Date
                    y=platform_data_grouped['rides'], # Y-axis: Total Rides
                    name=f'{platform} Rides' # Legend label name for the platform and Rides
                ))
                fig.add_trace(go.Scatter(
                    x=platform_data_grouped['daily_date'], # X-axis: Daily Date
                    y=platform_data_grouped['total_usd'], # Y-axis: Total USD
                    name=f'{platform} USD' # Legend label name for the platform and USD
                ))
    
        # Insert labels for the title, x-axis, y-axis and define sizing of the image.        
        fig.update_layout(
                            title="Daily Rides - USD by Platform",
                            xaxis_title="Date",
                            yaxis_title="Count",
                            width=width_pixels,
                            height=height_pixels,
                         )
    
        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_completed_usd_daily.html')          
        
        # Display the figure
        fig.show()

    # Create an interactive widget to update the line plot
    widget = interactive(
        update_line_plot, 
        start_date=start_date_picker, 
        end_date=end_date_picker, 
        start_age_range=start_age_range_picker, 
        end_age_range=end_age_range_picker,        
        start_platform=start_platform_range_picker, 
        end_platform=end_platform_range_picker,
        mergeplatforms=merge_platforms_checkbox
    )

    # Display the widgets
    display(widget)

# %%
# Create a function to display Average Rating by Age Range - Platform
def display_completed_ratings():
    # Load the dataset
    df = pd.read_csv('../CSV/funneldatawithdailydates.csv')
    # Set the funnel step
    df = df[df['funnel_step'] == 4]
    
    # Convert the 'daily_date' column to datetime
    df['daily_date'] = pd.to_datetime(df['daily_date'], format='%Y-%m-%d')

    # Filter the dataset based on the date range, age range and platform
    def filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform):
        start_date = pd.Timestamp(start_date).date()
        end_date = pd.Timestamp(end_date).date()
        filtered_df = df[
            (df['daily_date'].dt.date >= start_date) &
            (df['daily_date'].dt.date <= end_date) &
            (df['age_range'] >= start_age_range) &
            (df['age_range'] <= end_age_range) &
            (df['platform'] >= start_platform) &
            (df['platform'] <= end_platform)
        ]
        return filtered_df
  
    # Filter out 'Unknown' values from the age_range column
    filtered_age_ranges = df[df['age_range'] != 'Unknown']['age_range']

    # Sort the unique age range values with a custom sorting function
    unique_age_ranges = sorted(filtered_age_ranges.unique(), key=lambda x: [int(age) for age in x.split('-')])
    # Append 'Unknown' to the end of the sorted list
    unique_age_ranges.append('Unknown')     

    # Define default start and end age ranges
    default_start_age_range = '18-24'
    default_end_age_range = 'Unknown'
    
    # Create Dropdown Widgets for age range filtering option    
    start_age_range_picker = widgets.Dropdown(
        description='Start Age Range:',
        options=unique_age_ranges,
        value=default_start_age_range,
        disabled=False
    )
    end_age_range_picker = widgets.Dropdown(
        description='End Age Range:',
        options=unique_age_ranges,
        value=default_end_age_range,
        disabled=False
    )
    # Define default start and end platform ranges
    default_start_platform_range = 'android'
    default_end_platform_range = 'web'
     
    #Sort platform, drop nan values and set as string
    platform_options = sorted(df['platform'].dropna().astype(str).unique())  
    
    # Create Dropdown Widgets for platform filtering option    
    start_platform_range_picker = widgets.Dropdown(
        description='Start Platform:',
        options=platform_options,
        value=default_start_platform_range,
        disabled=False
    )
    end_platform_range_picker = widgets.Dropdown(
        description='End Platform:',
        options=platform_options,
        value=default_end_platform_range,
        disabled=False
    )

    # Update function for Average Rating by Age Range - Platform and call needed filters
    def update_bar_chart(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform, mergeages):
        if mergeages:
            # If the "Merge Ages" checkbox is checked, calculate the average rating for the total users
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            # Sort by age range and platform
            filtered_data = filtered_data.sort_values(by=["age_range", "platform"], ascending=[True, True])

            mean_data = filtered_data.groupby(['platform'])['avg_rating'].mean().reset_index()
            mean_data['avg_rating']= mean_data['avg_rating'].round(2)

            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()
            fig.add_trace(go.Bar(
                x=mean_data['platform'], # X-axis: Platform
                y=mean_data['avg_rating'], # Y-axis: Average Rating
                name='USD' # Legend label for USD
            ))
        else:
            # If "Merge Ages" is unchecked, display the data per platform
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            # Sort by age range and platform
            filtered_data = filtered_data.sort_values(by=["age_range", "platform"], ascending=[True, True])

            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()

            # Filter platform and age range for unique values
            platforms = filtered_data['platform'].unique()
            age_ranges = filtered_data['age_range'].unique()

            for age_range in age_ranges:
                # Loop through each unique age range in the dataset
                age_range_data = filtered_data[filtered_data['age_range'] == age_range]
                ratings_by_platform = []

                for platform in platforms:
                    # Calculate and store Average Rating for each platform in the dataset
                    platform_data = age_range_data[age_range_data['platform'] == platform]
                    mean_rating = platform_data['avg_rating'].mean()
                    mean_rating = round(mean_rating, 2)
                    ratings_by_platform.append(mean_rating)

                # Create a label that includes both age_range and platform information
                label = [f'{age_range} - {platform}' for platform in platforms]

                fig.add_trace(go.Bar(
                    x=label, # X-Axis: Combined label for age range and platform
                    y=ratings_by_platform, # Y-axis: Rating by Platform
                    name=age_range # Legend label for Age Range
                ))

        # Insert labels for the title, x-axis, y-axis and define sizing of the image.        
        fig.update_layout(
                            title="Average Rating by Age Range - Platform",
                            xaxis_title="Age Range - Platform",
                            yaxis_title="Average Rating",
                            width=width_pixels,
                            height=height_pixels,            
                         )

        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_completed_ratings.html')          
        
        # Display the figure
        fig.show()
    
    # Create an interactive widget to update the bar chart
    widget = interactive(
        update_bar_chart, 
        start_date=start_date_picker, 
        end_date=end_date_picker, 
        start_age_range=start_age_range_picker, 
        end_age_range=end_age_range_picker,
        start_platform=start_platform_range_picker,
        end_platform=end_platform_range_picker,
        mergeages=merge_agerange_checkbox
    )

    # Display the widgets
    display(widget)

# %%
# Create a function to display Drivers Ratings
def display_driver_ratings():
    # Load the dataset
    df = pd.read_csv('../CSV/unique_driver_ratings.csv')

    # Create a slider widget for filtering Higher than AVG.Rating
    higher_than_rating_slider = widgets.FloatSlider(
        value=0,
        min=0,
        max=df['avg_ratings'].max(),
        step=0.1,
        description='AVG.Rating >=',
        style={'description_width': 'initial'},
        layout=Layout(width='50%')
    )
    # Create a slider widget for filtering Lower than AVG.Rating
    lower_than_rating_slider = widgets.FloatSlider(
        value=2.5,
        min=0,
        max=df['avg_ratings'].max(),
        step=0.1,
        description='AVG.Rating <=',
        style={'description_width': 'initial'},
        layout=Layout(width='50%')
    )
    # Create a slider widget for filtering based on Reviews
    reviews_slider = widgets.FloatSlider(
        value=17,
        min=0,
        max=df['reviews'].max(),
        step=1,
        description='Number of Reviews',
        style={'description_width': 'initial'},
        layout=Layout(width='50%')        
    )
    # Create a slider widget for filtering based on Rides Completed
    rides_completed_slider = widgets.FloatSlider(
        value=21,
        min=0,
        max=df['rides_completed'].max(),
        step=1,
        description='Number of Rides Completed',
        style={'description_width': 'initial'},
        layout=Layout(width='50%')        
    )
    # Create an output widget to display the chart
    output = Output()
    
    # Function to create the bar chart
    def create_driver_ratings_chart(higher_than_rating_filter, lower_than_rating_filter, reviews_filter, rides_completed_filter):
        # Filter the data based on the sliders
        filtered_data = df[(df['avg_ratings'] >= higher_than_rating_filter)
                        & (df['avg_ratings'] <= lower_than_rating_filter)
                        & (df['reviews'] >= reviews_filter)
                        & (df['rides_completed'] >= rides_completed_filter)
        ]
        
        # Add image optimal figure sizing and quality for google docs.
        figsize_inches = (8.27, 5.87)
        dpi = 96
        width_pixels = int(figsize_inches[0] * dpi)
        height_pixels = int(figsize_inches[1] * dpi)
        
        fig = go.Figure()

        for driver_id in filtered_data['driver_id'].unique():
            driver_data = filtered_data[filtered_data['driver_id'] == driver_id]
            driver_id = driver_data['driver_id'].values[0]
            avg_rating = driver_data['avg_ratings'].values[0]
            reviews = driver_data['reviews'].values[0]
            rides_completed = driver_data['rides_completed'].values[0]
            fig.add_trace(go.Bar(
                x=[driver_id], # X-axis: Driver ID
                y=[avg_rating], # Y-axis: AVG.Rating
                name=driver_id, # Legend label for Driver ID
                hoverinfo='text',
                showlegend=False, # Prevents legend from being displayed
                text=f'Driver_id: {driver_id}<br>AVG.Rating: {avg_rating}<br>Reviews: {reviews}<br>Rides Completed: {rides_completed}'
                #Define the Hover Mouse text.
            ))

    # Insert labels for the title, x-axis, y-axis and define sizing of the image.        
        fig.update_layout(
            title='Average Ratings per Driver',
            xaxis_title='Driver ID',
            yaxis_title='AVG. Rating',
            width=width_pixels,
            height=height_pixels,
        )

        return fig

    # Function to update the chart based on the slider values
    def update_driver_ratings_chart(higher_than_rating_filter, lower_than_rating_filter, reviews_filter, rides_completed_filter):
        # Clear the previous output
        with output:
            output.clear_output()

        # Get the Plotly figure
        fig = create_driver_ratings_chart(higher_than_rating_filter, lower_than_rating_filter, reviews_filter, rides_completed_filter)

        # Transform the interactive Plotly chart into an HTML and save it.
        fig.write_html('../InteractiveGraphics/interactive_drivers_rating.html')

        # Display the figure
        fig.show()

    # Create an interactive widget to update the chart based on the slider values
    widget = interactive(
        update_driver_ratings_chart,
        higher_than_rating_filter=higher_than_rating_slider,
        lower_than_rating_filter=lower_than_rating_slider,
        reviews_filter=reviews_slider,
        rides_completed_filter=rides_completed_slider
    )

    # Display the widgets
    display(widget)

# %%
# Create a function to display Daily Reviews - AVG.Rating per Platform
def display_completed_reviews_daily():
    # Load the dataset
    df = pd.read_csv('../CSV/funneldatawithdailydates.csv')
    # Set the funnel step
    df = df[df['funnel_step'] == 4]
    # Convert the 'daily_date' column to datetime
    df['daily_date'] = pd.to_datetime(df['daily_date'], format='%Y-%m-%d')

    # Filter the dataset based on the date range, age range and platform
    def filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform):
        start_date = pd.Timestamp(start_date).date()
        end_date = pd.Timestamp(end_date).date()
        filtered_df = df[
        (df['daily_date'].dt.date >= start_date) & 
        (df['daily_date'].dt.date <= end_date) &
        (df['age_range'] >= start_age_range) & 
        (df['age_range'] <= end_age_range) &        
        (df['platform'] >= start_platform) &
        (df['platform'] <= end_platform)
        ]
        return filtered_df

    # Filter out 'Unknown' values from the age_range column
    filtered_age_ranges = df[df['age_range'] != 'Unknown']['age_range']

    # Sort the unique age range values with a custom sorting function
    unique_age_ranges = sorted(filtered_age_ranges.unique(), key=lambda x: [int(age) for age in x.split('-')])
    
    # Append 'Unknown' to the end of the sorted list
    unique_age_ranges.append('Unknown')     

    # Define default start and end age ranges
    default_start_age_range = '18-24'
    default_end_age_range = 'Unknown'
    
    # Create Dropdown Widgets for Age Range filtering option    
    start_age_range_picker = widgets.Dropdown(
        description='Start Age Range:',
        options=unique_age_ranges,
        value=default_start_age_range,
        disabled=False
    )
    end_age_range_picker = widgets.Dropdown(
        description='End Age Range:',
        options=unique_age_ranges,
        value=default_end_age_range,
        disabled=False
    )    
    # Define default start and end platform ranges
    default_start_platform_range = 'android'
    default_end_platform_range = 'web'

    # Sort platform, drop nan values and set as string
    platform_options = sorted(df['platform'].dropna().astype(str).unique())  
    
    # Create Dropdown Widgets for platform filtering option    
    start_platform_range_picker = widgets.Dropdown(
        description='Start Platform:',
        options=platform_options,
        value=default_start_platform_range,
        disabled=False
    )
    end_platform_range_picker = widgets.Dropdown(
        description='End Platform:',
        options=platform_options,
        value=default_end_platform_range,
        disabled=False
    )

    # Update function for the Daily Reviews - AVG.Rating per Platform and call needed filters
    def update_line_plot(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform, mergeplatforms):
        if mergeplatforms:
            # If the "Merge Platforms" checkbox is checked, calculate the total reviews and Average Rating for each platform
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            # Sort by platform
            filtered_data = filtered_data.sort_values(by="platform", ascending=True)
            total_reviews = filtered_data.groupby('daily_date')['total_reviews'].sum().reset_index()
            avg_rating = filtered_data.groupby('daily_date')['avg_rating'].mean().reset_index()

            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()
            fig.add_trace(go.Scatter(
                x=total_reviews['daily_date'], # X-axis: Daily Date
                y=total_reviews['total_reviews'], # Y-axis: Total Reviews
                name='Reviews' # Legend label for Reviews
            ))
            fig.add_trace(go.Scatter(
                x=avg_rating['daily_date'], # X-axis: Daily Date
                y=avg_rating['avg_rating'], # Y-axis: Average Rating
                name='Rating' # Legend label for Rating
            ))
        else:
            # If "Merge Platforms" is unchecked, display the data per platform
            filtered_data = filter_data(start_date, end_date, start_age_range, end_age_range, start_platform, end_platform)
            # Sort by platform
            filtered_data = filtered_data.sort_values(by="platform", ascending=True)

            # Add image optimal figure sizing and quality for google docs.            
            figsize_inches = (8.27, 5.87)
            dpi = 96
            width_pixels = int(figsize_inches[0] * dpi)
            height_pixels = int(figsize_inches[1] * dpi)
            
            fig = go.Figure()

            # Filter platform for unique values
            platforms = filtered_data['platform'].unique()
        
            for platform in platforms:
                # Calculate and store Total Reviews and Average Rating for each platform in the dataset
                platform_data = filtered_data[filtered_data['platform'] == platform]
                platform_data_reviews = platform_data.groupby('daily_date')['total_reviews'].sum().reset_index()
                platform_data_ratings = platform_data.groupby('daily_date')['avg_rating'].mean().reset_index()
                fig.add_trace(go.Scatter(
                    x=platform_data_reviews['daily_date'], # X-axis: Daily Date
                    y=platform_data_reviews['total_reviews'], # Y-axis: Total Reviews
                    name=f'{platform} Reviews' # Legend label name for the platform and Reviews
                ))
                fig.add_trace(go.Scatter(
                    x=platform_data_ratings['daily_date'], # X-axis: Daily Date
                    y=platform_data_ratings['avg_rating'], # Y-axis: Average Rating
                    name=f'{platform} Rating' # Legend label name for the platform and Rating
                ))
    
        # Insert labels for the title, x-axis, y-axis and define sizing of the image.        
        fig.update_layout(
                            title="Daily Reviews - AVG.Rating per Platform",
                            xaxis_title="Date",
                            yaxis_title="Counts",
                            width=width_pixels,
                            height=height_pixels,            
                         )
    
        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_completed_reviews_daily.html')   
        
        # Display the figure
        fig.show()
        
    # Create an interactive widget to update the line plot
    widget = interactive(
        update_line_plot, 
        start_date=start_date_picker, 
        end_date=end_date_picker, 
        start_age_range=start_age_range_picker, 
        end_age_range=end_age_range_picker,        
        start_platform=start_platform_range_picker, 
        end_platform=end_platform_range_picker,
        mergeplatforms=merge_platforms_checkbox
    )

    # Display the widgets
    display(widget)

# %%
# Create a function to display Full Cancellations vs. Full Completed Rides vs. Mixed
def display_binary_users():
    # Load your dataset
    df = pd.read_csv('../CSV/user_rides_stats.csv')

    # Create a new column to label users as 'Full Cancellations', 'Full Completed Rides', or 'Mixed'
    df['User Type'] = 'Mixed'
    df.loc[(df['rides_completed'] == 0) & (df['rides_canceled'] > 0), 'User Type'] = 'Full Cancellations'
    df.loc[(df['rides_completed'] > 0) & (df['rides_canceled'] == 0), 'User Type'] = 'Full Completed Rides'

    # Create slider widgets for filtering
    rides_canceled_slider = widgets.FloatSlider(
        value=0,
        min=0,
        max=df['rides_canceled'].max(),
        step=1,
        description='Filter Rides Canceled:',
        style={'description_width': 'initial'},
        layout=Layout(width='50%')
    )

    rides_completed_slider = widgets.FloatSlider(
        value=0,
        min=0,
        max=df['rides_completed'].max(),
        step=1,
        description='Filter Rides Completed:',
        style={'description_width': 'initial'},
        layout=Layout(width='50%')
    )

    total_rides_slider = widgets.FloatSlider(
        value=0,
        min=0,
        max=df['total_rides'].max(),
        step=1,
        description='Filter Total Rides:',
        style={'description_width': 'initial'},
        layout=Layout(width='50%')
    )

    # Function to create the scatter plot and filter the dataset on the rides canceled, completed and total rides
    def create_scatter(rides_canceled_filter, rides_completed_filter, total_rides_filter):
        filtered_data = df[
            (df['rides_canceled'] >= rides_canceled_filter) &
            (df['rides_completed'] >= rides_completed_filter) &
            (df['total_rides'] >= total_rides_filter)
        ]

        # Add image optimal figure sizing and quality for google docs.        
        figsize_inches = (8.27, 5.87)
        dpi = 96
        width_pixels = int(figsize_inches[0] * dpi)
        height_pixels = int(figsize_inches[1] * dpi)
        
        fig = go.Figure()

        # Add scatter traces for different user types
        user_types = filtered_data['User Type'].unique()
        colors = {'Mixed': 'gray', 'Full Cancellations': 'red', 'Full Completed Rides': 'blue'}

        for user_type in user_types:
            user_data = filtered_data[filtered_data['User Type'] == user_type]
            fig.add_trace(go.Scatter(
                x=user_data['user_id'], # X-axis: User ID
                y=user_data['total_rides'], # Y-axis: Total Rides
                mode='markers', # use markers for data points
                name=user_type, # legend label for User Type
                marker=dict(size=8, color=colors[user_type]), # Set marker size and color based on User Type
                text=user_type + "<br>Rides Canceled: " + user_data['rides_canceled'].astype(str) +
                     "<br>Rides Completed: " + user_data['rides_completed'].astype(str)
                # Show custom hover text with User ID, Rides Canceled and Rides completed
            ))

        # Insert labels for the title, x-axis, y-axis and define sizing of the image.        
        fig.update_layout(
            title='Full Cancellations vs. Full Completed Rides vs. Mixed',
            xaxis_title='User ID',
            yaxis_title='Rides',
            width=width_pixels,
            height=height_pixels,            
        )

        return fig

    # Function to update the Full Cancellations vs. Full Completed Rides vs. Mixed Scatter Plot
    def update_scatter(rides_canceled_filter, rides_completed_filter, total_rides_filter):
        fig = create_scatter(rides_canceled_filter, rides_completed_filter, total_rides_filter)

        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_binary_users.html')        

        # Display the figure
        fig.show()

    # Create an interactive widget to update the scatter plot based on the slider values
    widget = interactive(
        update_scatter,
        rides_canceled_filter=rides_canceled_slider,
        rides_completed_filter=rides_completed_slider,
        total_rides_filter=total_rides_slider
    )

    # Display the widgets
    display(widget)

# %%
# Create a function to display Users VS Drivers
def display_charge_users_drivers():
    # Load the dataset from the CSV file
    df = pd.read_csv('../CSV/chargestatistics.csv')

    # Add image optimal figure sizing and quality for google docs.    
    figsize_inches = (8.27, 5.87)
    dpi = 96
    width_pixels = int(figsize_inches[0] * dpi)
    height_pixels = int(figsize_inches[1] * dpi)
    
    fig = go.Figure()

    # Define the unique charge_status values
    charge_statuses = df['charge_status'].unique()

    # Loop through each charge_status
    for charge_status in charge_statuses:
        charge_status_data = df[df['charge_status'] == charge_status]
        users_count = charge_status_data['users'].values[0]
        drivers_count = charge_status_data['drivers'].values[0]
        fig.add_trace(go.Bar(
            x=['Users', 'Drivers'], # X-axis: Users & Drivers
            y=[users_count, drivers_count], # Y-axis: Users Count & Drivers Count
            name=charge_status, # Legend label for Charge Status
            hoverinfo='x+y+name', # Hover information combining x y and name
            text=[users_count, drivers_count], # Users Count & Drivers Count
            textposition='auto' # Set position to Auto
        ))

    # Insert labels for the title, x-axis, y-axis and define sizing of the image.
    fig.update_layout(
        title='Users VS Drivers',
        xaxis_title='Charge Status',
        yaxis_title='Count',
        barmode='group',
        width=width_pixels,
        height=height_pixels,        
    )
    # Transform the interactive Plotly chart into an Html and save it.
    fig.write_html('../InteractiveGraphics/interactive_charge_users_drivers.html')    
    
    # Display the figure
    fig.show()

# %%
# Create a function to display Rides VS Reviews
def display_charge_rides_reviews():
    # Load the dataset from the CSV file
    df = pd.read_csv('../CSV/chargestatistics.csv')

    # Add image optimal figure sizing and quality for google docs.    
    figsize_inches = (8.27, 5.87)
    dpi = 96
    width_pixels = int(figsize_inches[0] * dpi)
    height_pixels = int(figsize_inches[1] * dpi)
    
    fig = go.Figure()

    # Define the unique charge_status values
    charge_statuses = df['charge_status'].unique()

    # Loop through each charge_status
    for charge_status in charge_statuses:
        charge_status_data = df[df['charge_status'] == charge_status]
        rides_count = charge_status_data['rides'].values[0]
        reviews_count = charge_status_data['reviews'].values[0]
        fig.add_trace(go.Bar(
            x=['Rides', 'Reviews'], # X-axis: Rides & Reviews
            y=[rides_count, reviews_count], # Y-axis: Ride Counts & Review Counts
            name=charge_status, # Legend label for Charge Status
            hoverinfo='x+y+name', # Hover information combining x y and name
            text=[rides_count, reviews_count], # Ride Counts & Review Counts
            textposition='auto' # Set position to auto
        ))

    # Insert labels for the title, x-axis, y-axis and define sizing of the image.
    fig.update_layout(
        title='Rides VS Reviews',
        xaxis_title='Charge Status',
        yaxis_title='Count',
        barmode='group',
        width=width_pixels,
        height=height_pixels,        
    )
    # Transform the interactive Plotly chart into an Html and save it.
    fig.write_html('../InteractiveGraphics/interactive_charge_rides_reviews.html')
    
    # Display the Figure
    fig.show()

# %%
# Create a function to display Total USD by Charge Status
def display_charge_totalusd():
    # Load the dataset from the CSV file
    df = pd.read_csv('../CSV/chargestatistics.csv')

    # Add image optimal figure sizing and quality for google docs.    
    figsize_inches = (8.27, 5.87)
    dpi = 96
    width_pixels = int(figsize_inches[0] * dpi)
    height_pixels = int(figsize_inches[1] * dpi)
    
    fig = go.Figure()

    # Define the unique charge_status values
    charge_statuses = df['charge_status'].unique()

    # Loop through each charge_status
    for charge_status in charge_statuses:
        charge_status_data = df[df['charge_status'] == charge_status]
        totalusd = charge_status_data['total_usd'].values[0]
        fig.add_trace(go.Bar(
            x=[charge_status], # X-axis: Charge Status
            y=[totalusd], # Y-axis: Total USD
            name=charge_status, # Legend label for Charge Status
            hoverinfo='x+y', # Hover information combining x & y 
            text=[totalusd], # Total USD
            textposition='auto' # Set position to auto
        ))

    # Insert labels for the title, x-axis, y-axis and define sizing of the image.
    fig.update_layout(
        title='Total USD by Charge Status',
        xaxis_title='Charge Status',
        yaxis_title='Total USD',
        barmode='group',
        width=width_pixels,
        height=height_pixels,        
    )
    # Transform the interactive Plotly chart into an Html and save it.
    fig.write_html('../InteractiveGraphics/interactive_charge_totalusd.html')
    
    # Display the Figure
    fig.show()

# %%
# Create a function to display Lost & Gained Total USD by Users
def display_usd_users():
    # Load the dataset from the CSV file
    df = pd.read_csv('../CSV/user_declines.csv')

    # Create a slider widget for filtering lost_total_usd values
    lost_total_usd_slider = widgets.FloatSlider(
        value=0,  # Set the initial value to 0
        min=0,
        max=df['lost_total_usd'].max(),
        step=1,
        description='Lost Total USD Filter:',
        style={'description_width': 'initial'},
        layout=Layout(width='50%')
    )
    gained_total_usd_slider = widgets.FloatSlider(
        value=0,  # Set the initial value to 0
        min=0,
        max=df['gained_total_usd'].max(),
        step=1,
        description='Gained Total USD Filter:',
        style={'description_width': 'initial'},
        layout=Layout(width='50%')
    )

    # Create an output widget to display the chart
    output = Output()

    # Function to create the scatter plot 
    def create_usd_users_scatter(lost_total_usd_filter, gained_total_usd_filter):
        # Filter the data based on the slider value
        filtered_data = df[(df['lost_total_usd'] >= lost_total_usd_filter) & (df['gained_total_usd'] >= gained_total_usd_filter)]

        # Add image optimal figure sizing and quality for google docs.        
        figsize_inches = (8.27, 5.87)
        dpi = 96
        width_pixels = int(figsize_inches[0] * dpi)
        height_pixels = int(figsize_inches[1] * dpi)

        fig = go.Figure()

        # Add scatter traces for lost_total_usd and gained_total_usd
        fig.add_trace(go.Scatter(
            x=filtered_data['lost_total_usd'], # X-axis: Lost Total USD
            y=filtered_data['user_id'], # Y-axis: User ID
            mode='markers', # Use markers for data points
            marker=dict(size=10, color='red'),  # Customize marker color and size
            name='Lost Total USD' # Legend label for Lost Total USD
        ))

        fig.add_trace(go.Scatter(
            x=filtered_data['gained_total_usd'], # X-axis: Gained Total USD
            y=filtered_data['user_id'], # Y-axis: User ID
            mode='markers', # Use markers for data points
            marker=dict(size=10, color='blue'),  # Customize marker color and size
            name='Gained Total USD' # Legend label for Gained Total USD
        ))

        # Insert labels for the title, x-axis, y-axis and define sizing of the image.        
        fig.update_layout(
            title='Lost & Gained Total USD by Users',
            xaxis_title='Total USD',
            yaxis_title='User ID',
            width=width_pixels,
            height=height_pixels,            
        )

        return fig

    # Function to update the Lost & Gained Total USD by Users based on the slider value
    def update_usd_users_scatter(lost_total_usd_filter, gained_total_usd_filter):
        # Clear the previous output
        with output:
            output.clear_output()

        # Get the Plotly figure
        fig = create_usd_users_scatter(lost_total_usd_filter, gained_total_usd_filter)

        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_usd_users.html')            
        
        # Display the figure
        fig.show()

    # Create an interactive widget to update the scatter plot based on the slider value
    widget = interactive(update_usd_users_scatter, lost_total_usd_filter=lost_total_usd_slider, gained_total_usd_filter=gained_total_usd_slider)

    # Display the widgets
    display(widget)

# %%
# Create a function to display Lost & Gained Total USD by Drivers
def display_usd_drivers():
    # Load the dataset from the CSV file
    df = pd.read_csv('../CSV/driver_declines.csv')

    # Create a slider widget for filtering lost_total_usd values
    lost_total_usd_slider = widgets.FloatSlider(
        value=0,  # Set the initial value to 0
        min=0,
        max=df['lost_total_usd'].max(),
        step=1,
        description='Lost Total USD Filter:',
        style={'description_width': 'initial'},
        layout=Layout(width='50%')
    )
    gained_total_usd_slider = widgets.FloatSlider(
        value=0,  # Set the initial value to 0
        min=0,
        max=df['gained_total_usd'].max(),
        step=1,
        description='Gained Total USD Filter:',
        style={'description_width': 'initial'},
        layout=Layout(width='50%')
    )

    # Create an output widget to display the chart
    output = Output()

    # Function to create the scatter plot
    def create_usd_drivers_scatter(lost_total_usd_filter, gained_total_usd_filter):
        # Filter the data based on the slider value
        filtered_data = df[(df['lost_total_usd'] >= lost_total_usd_filter) & (df['gained_total_usd'] >= gained_total_usd_filter)]

        # Add image optimal figure sizing and quality for google docs.        
        figsize_inches = (8.27, 5.87)
        dpi = 96
        width_pixels = int(figsize_inches[0] * dpi)
        height_pixels = int(figsize_inches[1] * dpi)
        
        fig = go.Figure()

        # Add scatter traces for lost_total_usd and gained_total_usd
        fig.add_trace(go.Scatter(
            x=filtered_data['lost_total_usd'], # X-axis: Lost Total USD
            y=filtered_data['driver_id'], # Y-axis: Driver ID
            mode='markers', # Use markers for data points
            marker=dict(size=10, color='red'),  # Customize marker color and size
            name='Lost Total USD' # Legend label for Lost Total USD
        ))

        fig.add_trace(go.Scatter(
            x=filtered_data['gained_total_usd'], # X-axis: Gained Total USD
            y=filtered_data['driver_id'], # Y-axis: Driver ID
            mode='markers', # Use markers for data points
            marker=dict(size=10, color='blue'),  # Customize marker color and size 
            name='Gained Total USD' # Legend label for Gained Total USD 
        ))

        # Insert labels for the title, x-axis, y-axis and define sizing of the image.        
        fig.update_layout(
            title='Lost & Gained Total USD by Drivers',
            xaxis_title='Total USD',
            yaxis_title='Driver ID',
            width=width_pixels,
            height=height_pixels,
        )

        return fig

    # Function to update the Lost & Gained Total USD by Drivers based on the slider value
    def update_usd_drivers_scatter(lost_total_usd_filter, gained_total_usd_filter):
        # Clear the previous output
        with output:
            output.clear_output()

        # Get the Plotly figure
        fig = create_usd_drivers_scatter(lost_total_usd_filter, gained_total_usd_filter)

        # Transform the interactive Plotly chart into an Html and save it.
        fig.write_html('../InteractiveGraphics/interactive_usd_drivers.html') 
        
        # Display the figure
        fig.show()

    # Create an interactive widget to update the scatter plot based on the slider value
    widget = interactive(update_usd_drivers_scatter, lost_total_usd_filter=lost_total_usd_slider, gained_total_usd_filter=gained_total_usd_slider)

    # Display the widgets
    display(widget)

# %%
# Define the main categories and their respective subcategories
categories = {
    'Funnel': ['User Funnel', 'Rides Funnel'],
    'Downloads': ['Daily Downloads per Platform'],
    'Signups': [
                'Signups by Age Range - Platform',
                'Daily Signups per Platform'
               ],
    'Rides Requested': [
                        'Ride Requested Users by Age Range - Platform',
                        'Ride Requests by Age Range - Platform',
                        'Daily Rides & Cancellations per Platform',
                        'Surge-Pricing', 'Minimum Rides Per User'
                       ],
    'Rides Completed': [
                        'Rides Completed Users by Age Range - Platform',
                        'Rides Completed by Age Range - Platform',
                        'USD by Age Range - Platform',
                        'Daily Rides - USD per Platform',
                        'Average Rating by Age Range - Platform',
                        'Average Rating per Driver',
                        'Daily Reviews - AVG.Rating per Platform',
                        'Binary User Behaviour',
                       ],
    'Charge Status':[
                     'Users VS Drivers',
                     'Rides VS Reviews',
                     'Total USD by Charge Status',
                     'Lost & Gained Total USD by Users',
                     'Lost & Gained Total USD by Drivers',
                    ],
}

# Create dropdown widgets for main categories and subcategories
main_category_selector = widgets.Dropdown(
    options=categories.keys(),
    description='Main Category:'
)

subcategory_selector = widgets.Dropdown(
    options=categories[main_category_selector.value],
    description='Subcategory:'
)

# Function to update subcategories based on the selected main category
def update_subcategories(change):
    subcategory_selector.options = categories[change.new]

main_category_selector.observe(update_subcategories, names='value')

#Set default visualization for loading

def set_default_visualization():
    selected_visualization = 'User Funnel'
    display_visualization(selected_visualization)
   

# Display the selected visualization based on the chosen subcategory
def display_visualization(selected_visualization):
    with output:
        output.clear_output()
        if selected_visualization == 'User Funnel':
            display_funnel_users_visualization()
        elif selected_visualization == 'Rides Funnel':
            display_funnel_rides_visualization()
        elif selected_visualization == 'Daily Downloads per Platform':
            display_download_platform()
        elif selected_visualization == 'Signups by Age Range - Platform':
            display_signups_visualization()
        elif selected_visualization == 'Daily Signups per Platform':
            display_signupsdaily_visualization()
        elif selected_visualization == 'Ride Requested Users by Age Range - Platform':
            display_user_by_riderequests_visualization()
        elif selected_visualization == 'Ride Requests by Age Range - Platform':
            display_riderequests_visualization()
        elif selected_visualization == 'Daily Rides & Cancellations per Platform':
            display_rides_cancellations_visualization()
        elif selected_visualization == 'Surge-Pricing':
            display_surge_pricing()
        elif selected_visualization == 'Minimum Rides Per User':
            display_minridesperuser()            
        elif selected_visualization == 'Rides Completed Users by Age Range - Platform':
            display_user_by_ridecompletes_visualization()         
        elif selected_visualization == 'Rides Completed by Age Range - Platform':
            display_completed_age_platform()
        elif selected_visualization == 'USD by Age Range - Platform':
            display_completed_usd()            
        elif selected_visualization == 'Daily Rides - USD per Platform':
            display_completed_usd_daily()            
        elif selected_visualization == 'Average Rating by Age Range - Platform':
            display_completed_ratings()
        elif selected_visualization == 'Average Rating per Driver':
            display_driver_ratings()
        elif selected_visualization == 'Daily Reviews - AVG.Rating per Platform':
            display_completed_reviews_daily()
        elif selected_visualization == 'Binary User Behaviour':
            display_binary_users()
        elif selected_visualization == 'Users VS Drivers':
            display_charge_users_drivers()
        elif selected_visualization == 'Rides VS Reviews':
            display_charge_rides_reviews()
        elif selected_visualization == 'Total USD by Charge Status':
            display_charge_totalusd()
        elif selected_visualization == 'Lost & Gained Total USD by Users':
            display_usd_users() 
        elif selected_visualization == 'Lost & Gained Total USD by Drivers':
            display_usd_drivers()


# Set up the event handler for the subcategory value change
widgets.interactive(display_visualization, selected_visualization=subcategory_selector)

# Create an output widget for displaying the visualizations
output = widgets.Output()

# Display the main category and subcategory dropdowns, along with the output widget
display(main_category_selector, subcategory_selector, output)
set_default_visualization()
# Out:
# Dropdown(description='Main Category:', options=('Funnel', 'Downloads', 'Signups', 'Rides Requested', 'Rides Co…
# Dropdown(description='Subcategory:', options=('User Funnel', 'Rides Funnel'), value='User Funnel')
# Output()
